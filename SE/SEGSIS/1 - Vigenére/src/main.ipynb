# %%
from pathlib import Path
from collections import Counter

# %%
alphabet = 'abcdefghijklmnopqrstuvwxyz'

cipher_texts_dir = Path("../textos-cifrados-20230312")
test_english = "../test/cipher_text_english.txt"
test_portuguese = "../test/texto_cifrado_portugues.txt"

# portuguese 5 most frequent letters
pt_fmfl = "aeors"

# english 5 most frequent letters
en_fmfl = "aeiot"

# %%
def index_of_coincidence(word):
    coincidence_index = 0
    n = len(word)
    occurrences = list(Counter(word).values())
    for occurrence in occurrences:
        coincidence_index += occurrence / n * (occurrence - 1) / (n - 1)
    return round(coincidence_index, 3)

# %%
def find_key_length(cipher_text):
    print("| m | Ic")
    print("|-------")

    key_length = 1
    while key_length < (len(cipher_text) / 2):
        print(f"| {key_length} |", end=" ")
        
        substrings = [cipher_text[i::key_length] for i in range(key_length)]
        indexes = [index_of_coincidence(substring) for substring in substrings]
        print(indexes)

        diff = round(abs(sum(indexes) / len(indexes) - 0.067), 3)
        if 0 <= diff <= 0.002:
            break

        diff = round(abs(sum(indexes) / len(indexes) - 0.081), 3)
        if 0 <= diff <= 0.005:
            break

        key_length += 1
    print()
    
    return key_length

# %%
def generate_possible_keys(cipher_text, key_length):
    substrings = [cipher_text[i::key_length] for i in range(key_length)]
    occurrences = [[key for key, _ in Counter(substring).most_common()] for substring in substrings]
    possible_keys = ["".join([occurrence[index] for occurrence in occurrences if index < len(occurrence)]) for index in range(len(alphabet))]
    return possible_keys[:5]

# %%
def decrypt(cipher_text, possible_keys):
    plaintext = ""
    for key in possible_keys:
        for index in range(0, len(cipher_text), len(key)):
            chunk = cipher_text[index : index + len(key)]
            for char, dist in zip(chunk, key):
                a = ord(char) - ord(dist)
                plaintext += alphabet[a]

        most_freq_chars = "".join(sorted([key for key, _ in Counter(plaintext).most_common(5)]))

        if most_freq_chars in [pt_fmfl, en_fmfl]:
            print(key, "\n")
            break
         
        plaintext = ""
            
    return plaintext

# %%
def decrypt2(cipher_text, possible_keys, key_length):
    chunks = [cipher_text[index : index + key_length] for index in range(0, len(cipher_text), key_length)]
    
    plaintext = ""
    for key in possible_keys:
        for chunk in chunks:
            distances = [ord(char) - ord(dist) for char, dist in zip(chunk, key)]
            plaintext += "".join([alphabet[distance] for distance in distances])
    
        fmfl = "".join(sorted([key for key, _ in Counter(plaintext).most_common(5)]))

        if fmfl in [pt_fmfl, en_fmfl]:
            print(key, "\n")
            break
         
        plaintext = ""
            
    return plaintext

# %%
with open(test_english, "r") as file:
    cipher_text = file.read()

key_length = find_key_length(cipher_text)

possible_keys = generate_possible_keys(cipher_text, key_length)
print(possible_keys)
print()

plaintext = decrypt2(cipher_text, possible_keys, key_length)
print("plaintext:", plaintext[:50])

with open(f"../out/{test_english[8:]}", "w") as file:
    file.write(plaintext)
# Out:
# | m | Ic
# |-------
# | 1 | [0.042]
# | 2 | [0.042, 0.042]
# | 3 | [0.042, 0.042, 0.042]
# | 4 | [0.042, 0.042, 0.042, 0.042]
# | 5 | [0.042, 0.042, 0.042, 0.042, 0.042]
# | 6 | [0.042, 0.042, 0.042, 0.043, 0.042, 0.042]
# | 7 | [0.067, 0.067, 0.067, 0.067, 0.067, 0.067, 0.067]
#
# ['qiyrsqi', 'fxnghfx', 'meunome', 'asibcas', 'umcvwum']
#
# meunome
#
# plaintext: thisebookisfortheuseofanyoneanywhereatnocostandwit

# %%
with open(test_portuguese, "r") as file:
    cipher_text = file.read()

key_length = find_key_length(cipher_text)

possible_keys = generate_possible_keys(cipher_text, key_length)
print(possible_keys)
print()

plaintext = decrypt(cipher_text, ["meunome"])
print("plaintext:", plaintext[:50])

with open(f"../out/{test_portuguese[8:]}", "w") as file:
    file.write(plaintext)
# Out:
# | m | Ic
# |-------
# | 1 | [0.046]
# | 2 | [0.045, 0.046]
# | 3 | [0.046, 0.046, 0.046]
# | 4 | [0.045, 0.046, 0.046, 0.047]
# | 5 | [0.046, 0.046, 0.046, 0.046, 0.046]
# | 6 | [0.045, 0.046, 0.045, 0.047, 0.045, 0.046]
# | 7 | [0.077, 0.074, 0.077, 0.076, 0.077, 0.076, 0.077]
#
# ['miyrsqe', 'qeunomi', 'asibcas', 'ewlfgew', 'uvmewuv']
#
# meunome
#
# plaintext: quemhacincoentaannostivesseacoragemdepublicarumliv

# %%
for cipher_text_file in cipher_texts_dir.iterdir():
  print(cipher_text_file.name, "\n")
  with open(cipher_text_file, "r") as file:
    cipher_text = file.read()

  key_length = find_key_length(cipher_text)

  possible_keys = generate_possible_keys(cipher_text, key_length)
  print(possible_keys)
  print()

  plaintext = decrypt(cipher_text, possible_keys)
  print("plaintext:", plaintext[:50])
  print()

  with open(f"../out/{cipher_text_file.name}", "w") as file:
    file.write(plaintext)
# Out:
# cipher1.txt
#
# | m | Ic
# |-------
# | 1 | [0.042]
# | 2 | [0.045, 0.047]
# | 3 | [0.042, 0.042, 0.042]
# | 4 | [0.058, 0.058, 0.059, 0.054]
# | 5 | [0.042, 0.042, 0.042, 0.042, 0.042]
# | 6 | [0.045, 0.048, 0.045, 0.047, 0.045, 0.047]
# | 7 | [0.042, 0.042, 0.042, 0.042, 0.042, 0.042, 0.042]
# | 8 | [0.081, 0.081, 0.081, 0.081, 0.082, 0.081, 0.081, 0.082]
#
# ['gvmwxmer', 'cristian', 'qfwghwob', 'ujaklasf', 'tizjkzre']
#
# cristian
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher10.txt
#
# | m | Ic
# |-------
# | 1 | [0.043]
# | 2 | [0.055, 0.048]
# | 3 | [0.059, 0.065, 0.056]
# | 4 | [0.055, 0.048, 0.055, 0.048]
# | 5 | [0.043, 0.043, 0.043, 0.043, 0.043]
# | 6 | [0.081, 0.082, 0.081, 0.081, 0.081, 0.081]
#
# ['verkip', 'rangel', 'fobusz', 'jsfywd', 'irexvc']
#
# rangel
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher11.txt
#
# | m | Ic
# |-------
# | 1 | [0.043]
# | 2 | [0.043, 0.043]
# | 3 | [0.05, 0.068, 0.052]
# | 4 | [0.043, 0.043, 0.043, 0.043]
# | 5 | [0.043, 0.043, 0.043, 0.043, 0.043]
# | 6 | [0.05, 0.068, 0.052, 0.05, 0.068, 0.052]
# | 7 | [0.042, 0.043, 0.043, 0.043, 0.043, 0.043, 0.043]
# | 8 | [0.043, 0.043, 0.042, 0.043, 0.043, 0.043, 0.043, 0.043]
# | 9 | [0.081, 0.081, 0.081, 0.081, 0.082, 0.081, 0.081, 0.081, 0.081]
#
# ['nivywepiq', 'jerusalem', 'xsfigozsa', 'bwjmksdwe', 'aviljrcvd']
#
# jerusalem
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher12.txt
#
# | m | Ic
# |-------
# | 1 | [0.045]
# | 2 | [0.051, 0.049]
# | 3 | [0.045, 0.045, 0.045]
# | 4 | [0.065, 0.067, 0.067, 0.059]
# | 5 | [0.045, 0.045, 0.045, 0.045, 0.045]
# | 6 | [0.051, 0.049, 0.051, 0.049, 0.051, 0.049]
# | 7 | [0.045, 0.045, 0.045, 0.045, 0.045, 0.045, 0.045]
# | 8 | [0.081, 0.081, 0.081, 0.081, 0.082, 0.081, 0.081, 0.082]
#
# ['wsjxaevi', 'software', 'gcthkofs', 'kgxlosjw', 'jfwknriv']
#
# software
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher13.txt
#
# | m | Ic
# |-------
# | 1 | [0.046]
# | 2 | [0.056, 0.059]
# | 3 | [0.046, 0.046, 0.046]
# | 4 | [0.081, 0.081, 0.081, 0.081]
#
# ['mksv', 'igor', 'wucf', 'aygj', 'zxfi']
#
# igor
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher14.txt
#
# | m | Ic
# |-------
# | 1 | [0.046]
# | 2 | [0.046, 0.046]
# | 3 | [0.048, 0.05, 0.059]
# | 4 | [0.046, 0.046, 0.046, 0.046]
# | 5 | [0.046, 0.046, 0.046, 0.046, 0.046]
# | 6 | [0.048, 0.05, 0.059, 0.048, 0.05, 0.059]
# | 7 | [0.046, 0.046, 0.046, 0.046, 0.046, 0.046, 0.046]
# | 8 | [0.046, 0.046, 0.046, 0.046, 0.046, 0.046, 0.046, 0.046]
# | 9 | [0.081, 0.081, 0.081, 0.081, 0.082, 0.081, 0.081, 0.081, 0.081]
#
# ['nsestihvs', 'joaopedro', 'xcocdsrfc', 'bgsghwvjg', 'afrfgvuif']
#
# joaopedro
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher15.txt
#
# | m | Ic
# |-------
# | 1 | [0.046]
# | 2 | [0.046, 0.046]
# | 3 | [0.046, 0.046, 0.046]
# | 4 | [0.046, 0.046, 0.046, 0.046]
# | 5 | [0.081, 0.081, 0.081, 0.081, 0.081]
#
# ['wximr', 'stein', 'ghswb', 'klwaf', 'jkvze']
#
# stein
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher16.txt
#
# | m | Ic
# |-------
# | 1 | [0.043]
# | 2 | [0.043, 0.043]
# | 3 | [0.043, 0.043, 0.043]
# | 4 | [0.043, 0.043, 0.043, 0.043]
# | 5 | [0.043, 0.043, 0.043, 0.043, 0.043]
# | 6 | [0.043, 0.043, 0.043, 0.043, 0.043, 0.043]
# | 7 | [0.081, 0.081, 0.081, 0.081, 0.081, 0.081, 0.081]
#
# ['wglypiv', 'schuler', 'gqvizsf', 'kuzmdwj', 'jtylcvi']
#
# schuler
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher17.txt
#
# | m | Ic
# |-------
# | 1 | [0.044]
# | 2 | [0.044, 0.044]
# | 3 | [0.044, 0.044, 0.044]
# | 4 | [0.044, 0.044, 0.044, 0.044]
# | 5 | [0.044, 0.044, 0.044, 0.044, 0.044]
# | 6 | [0.044, 0.044, 0.044, 0.044, 0.044, 0.044]
# | 7 | [0.081, 0.081, 0.081, 0.081, 0.081, 0.081, 0.081]
#
# ['qevgips', 'marcelo', 'aofqszc', 'esjuwdg', 'dritvcf']
#
# marcelo
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher18.txt
#
# | m | Ic
# |-------
# | 1 | [0.045]
# | 2 | [0.05, 0.058]
# | 3 | [0.059, 0.056, 0.06]
# | 4 | [0.05, 0.058, 0.05, 0.058]
# | 5 | [0.045, 0.045, 0.045, 0.045, 0.045]
# | 6 | [0.081, 0.082, 0.081, 0.081, 0.081, 0.081]
#
# ['qexiyw', 'mateus', 'aohsig', 'eslwmk', 'drkvlj']
#
# mateus
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher19.txt
#
# | m | Ic
# |-------
# | 1 | [0.044]
# | 2 | [0.044, 0.044]
# | 3 | [0.044, 0.044, 0.044]
# | 4 | [0.044, 0.044, 0.044, 0.044]
# | 5 | [0.044, 0.044, 0.044, 0.044, 0.044]
# | 6 | [0.044, 0.044, 0.044, 0.044, 0.044, 0.044]
# | 7 | [0.081, 0.081, 0.081, 0.081, 0.081, 0.081, 0.081]
#
# ['qexliyw', 'matheus', 'aohvsig', 'eslzwmk', 'drkyvlj']
#
# matheus
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher2.txt
#
# | m | Ic
# |-------
# | 1 | [0.047]
# | 2 | [0.047, 0.047]
# | 3 | [0.047, 0.047, 0.047]
# | 4 | [0.047, 0.047, 0.047, 0.047]
# | 5 | [0.081, 0.081, 0.081, 0.081, 0.081]
#
# ['hezmh', 'david', 'rojwr', 'vsnav', 'urmzu']
#
# david
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher20.txt
#
# | m | Ic
# |-------
# | 1 | [0.045]
# | 2 | [0.045, 0.045]
# | 3 | [0.045, 0.045, 0.045]
# | 4 | [0.045, 0.045, 0.045, 0.045]
# | 5 | [0.045, 0.045, 0.045, 0.045, 0.045]
# | 6 | [0.045, 0.045, 0.045, 0.045, 0.045, 0.045]
# | 7 | [0.081, 0.081, 0.081, 0.081, 0.081, 0.081, 0.081]
#
# ['qexlmew', 'mathias', 'aohvwog', 'eslzask', 'drkyzrj']
#
# mathias
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher21.txt
#
# | m | Ic
# |-------
# | 1 | [0.046]
# | 2 | [0.046, 0.046]
# | 3 | [0.046, 0.046, 0.046]
# | 4 | [0.046, 0.046, 0.046, 0.046]
# | 5 | [0.081, 0.081, 0.081, 0.081, 0.081]
#
# ['teyps', 'paulo', 'doizc', 'hsmdg', 'grlcf']
#
# paulo
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher22.txt
#
# | m | Ic
# |-------
# | 1 | [0.049]
# | 2 | [0.051, 0.05]
# | 3 | [0.056, 0.065, 0.056]
# | 4 | [0.051, 0.05, 0.051, 0.05]
# | 5 | [0.049, 0.049, 0.049, 0.049, 0.049]
# | 6 | [0.081, 0.082, 0.081, 0.081, 0.081, 0.081]
#
# ['vmxxiv', 'ritter', 'fwhhsf', 'jallwj', 'izkkvi']
#
# ritter
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher23.txt
#
# | m | Ic
# |-------
# | 1 | [0.043]
# | 2 | [0.044, 0.047]
# | 3 | [0.043, 0.043, 0.043]
# | 4 | [0.044, 0.047, 0.044, 0.047]
# | 5 | [0.059, 0.054, 0.056, 0.056, 0.059]
# | 6 | [0.044, 0.047, 0.044, 0.047, 0.044, 0.047]
# | 7 | [0.043, 0.043, 0.043, 0.043, 0.043, 0.043, 0.043]
# | 8 | [0.044, 0.047, 0.044, 0.047, 0.044, 0.047, 0.045, 0.047]
# | 9 | [0.043, 0.043, 0.043, 0.043, 0.043, 0.043, 0.043, 0.043, 0.043]
# | 10 | [0.081, 0.081, 0.081, 0.081, 0.081, 0.082, 0.081, 0.081, 0.081, 0.081]
#
# ['gsqterlsrm', 'companhoni', 'qcadobvcbw', 'ugehsfzgfa', 'tfdgreyfez']
#
# companhoni
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher24.txt
#
# | m | Ic
# |-------
# | 1 | [0.046]
# | 2 | [0.046, 0.046]
# | 3 | [0.046, 0.046, 0.046]
# | 4 | [0.046, 0.046, 0.046, 0.046]
# | 5 | [0.046, 0.046, 0.046, 0.046, 0.046]
# | 6 | [0.046, 0.046, 0.046, 0.046, 0.046, 0.046]
# | 7 | [0.081, 0.081, 0.081, 0.081, 0.081, 0.081, 0.081]
#
# ['gehezep', 'cadaval', 'qorojoz', 'usvsnsd', 'trurmrc']
#
# cadaval
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher25.txt
#
# | m | Ic
# |-------
# | 1 | [0.047]
# | 2 | [0.052, 0.067]
# | 3 | [0.058, 0.059, 0.062]
# | 4 | [0.052, 0.067, 0.052, 0.067]
# | 5 | [0.047, 0.047, 0.047, 0.047, 0.047]
# | 6 | [0.081, 0.082, 0.081, 0.081, 0.081, 0.081]
#
# ['virexe', 'renata', 'fsboho', 'jwfsls', 'iverkr']
#
# renata
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher26.txt
#
# | m | Ic
# |-------
# | 1 | [0.046]
# | 2 | [0.046, 0.046]
# | 3 | [0.046, 0.046, 0.046]
# | 4 | [0.046, 0.046, 0.046, 0.046]
# | 5 | [0.046, 0.046, 0.046, 0.046, 0.046]
# | 6 | [0.046, 0.046, 0.046, 0.046, 0.046, 0.046]
# | 7 | [0.081, 0.081, 0.081, 0.081, 0.081, 0.081, 0.081]
#
# ['vmgevhs', 'ricardo', 'fwqofrc', 'jausjvg', 'iztriuf']
#
# ricardo
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher27.txt
#
# | m | Ic
# |-------
# | 1 | [0.046]
# | 2 | [0.046, 0.046]
# | 3 | [0.046, 0.046, 0.046]
# | 4 | [0.046, 0.046, 0.046, 0.046]
# | 5 | [0.046, 0.046, 0.046, 0.046, 0.046]
# | 6 | [0.046, 0.046, 0.046, 0.046, 0.046, 0.046]
# | 7 | [0.081, 0.081, 0.081, 0.081, 0.081, 0.081, 0.081]
#
# ['vshvmks', 'rodrigo', 'fcrfwuc', 'jgvjayg', 'ifuizxf']
#
# rodrigo
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher28.txt
#
# | m | Ic
# |-------
# | 1 | [0.048]
# | 2 | [0.051, 0.054]
# | 3 | [0.067, 0.059, 0.067]
# | 4 | [0.051, 0.054, 0.051, 0.054]
# | 5 | [0.048, 0.048, 0.048, 0.048, 0.048]
# | 6 | [0.081, 0.082, 0.081, 0.081, 0.081, 0.081]
#
# ['fvergs', 'branco', 'pfobqc', 'tjsfug', 'siretf']
#
# branco
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher29.txt
#
# | m | Ic
# |-------
# | 1 | [0.045]
# | 2 | [0.044, 0.045]
# | 3 | [0.044, 0.045, 0.045]
# | 4 | [0.044, 0.045, 0.044, 0.045]
# | 5 | [0.081, 0.081, 0.081, 0.081, 0.081]
#
# ['ovsxl', 'kroth', 'yfchv', 'cjglz', 'bifky']
#
# kroth
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher3.txt
#
# | m | Ic
# |-------
# | 1 | [0.045]
# | 2 | [0.045, 0.045]
# | 3 | [0.045, 0.045, 0.045]
# | 4 | [0.045, 0.045, 0.045, 0.045]
# | 5 | [0.081, 0.081, 0.081, 0.081, 0.081]
#
# ['hmiks', 'diego', 'rwsuc', 'vawyg', 'uzvxf']
#
# diego
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher30.txt
#
# | m | Ic
# |-------
# | 1 | [0.046]
# | 2 | [0.046, 0.046]
# | 3 | [0.051, 0.068, 0.048]
# | 4 | [0.046, 0.046, 0.046, 0.046]
# | 5 | [0.046, 0.046, 0.046, 0.046, 0.046]
# | 6 | [0.051, 0.068, 0.048, 0.051, 0.068, 0.048]
# | 7 | [0.046, 0.046, 0.046, 0.046, 0.046, 0.046, 0.046]
# | 8 | [0.046, 0.046, 0.046, 0.046, 0.046, 0.046, 0.046, 0.046]
# | 9 | [0.081, 0.081, 0.081, 0.081, 0.082, 0.081, 0.081, 0.081, 0.081]
#
# ['zmvkmpmyw', 'virgilius', 'jwfuwzwig', 'najyadamk', 'mzixzczlj']
#
# virgilius
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher31.txt
#
# | m | Ic
# |-------
# | 1 | [0.044]
# | 2 | [0.044, 0.044]
# | 3 | [0.044, 0.044, 0.044]
# | 4 | [0.044, 0.044, 0.044, 0.044]
# | 5 | [0.081, 0.081, 0.081, 0.081, 0.081]
#
# ['zmxsv', 'vitor', 'jwhcf', 'nalgj', 'mzkfi']
#
# vitor
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher4.txt
#
# | m | Ic
# |-------
# | 1 | [0.047]
# | 2 | [0.047, 0.047]
# | 3 | [0.047, 0.047, 0.047]
# | 4 | [0.047, 0.047, 0.047, 0.047]
# | 5 | [0.047, 0.047, 0.047, 0.047, 0.047]
# | 6 | [0.047, 0.047, 0.047, 0.047, 0.047, 0.047]
# | 7 | [0.081, 0.081, 0.081, 0.081, 0.081, 0.081, 0.081]
#
# ['ihyevhs', 'eduardo', 'sriofrc', 'wvmsjvg', 'vulriuf']
#
# eduardo
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher5.txt
#
# | m | Ic
# |-------
# | 1 | [0.047]
# | 2 | [0.054, 0.067]
# | 3 | [0.057, 0.059, 0.054]
# | 4 | [0.054, 0.067, 0.054, 0.067]
# | 5 | [0.047, 0.047, 0.047, 0.047, 0.047]
# | 6 | [0.081, 0.082, 0.081, 0.081, 0.081, 0.081]
#
# ['jipmti', 'felipe', 'tszwds', 'xwdahw', 'wvczgv']
#
# felipe
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher6.txt
#
# | m | Ic
# |-------
# | 1 | [0.044]
# | 2 | [0.044, 0.044]
# | 3 | [0.044, 0.044, 0.044]
# | 4 | [0.044, 0.044, 0.044, 0.044]
# | 5 | [0.044, 0.044, 0.044, 0.044, 0.044]
# | 6 | [0.044, 0.044, 0.044, 0.044, 0.044, 0.044]
# | 7 | [0.081, 0.081, 0.081, 0.081, 0.081, 0.081, 0.081]
#
# ['kmvsxxs', 'girotto', 'uwfchhc', 'yajgllg', 'xzifkkf']
#
# girotto
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher7.txt
#
# | m | Ic
# |-------
# | 1 | [0.046]
# | 2 | [0.046, 0.046]
# | 3 | [0.046, 0.046, 0.046]
# | 4 | [0.046, 0.046, 0.046, 0.046]
# | 5 | [0.046, 0.046, 0.046, 0.046, 0.046]
# | 6 | [0.046, 0.046, 0.046, 0.046, 0.046, 0.046]
# | 7 | [0.081, 0.081, 0.081, 0.081, 0.081, 0.081, 0.081]
#
# ['kviksvc', 'gregory', 'ufsucfm', 'yjwygjq', 'xivxfip']
#
# gregory
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher8.txt
#
# | m | Ic
# |-------
# | 1 | [0.043]
# | 2 | [0.054, 0.048]
# | 3 | [0.043, 0.043, 0.043]
# | 4 | [0.06, 0.054, 0.058, 0.067]
# | 5 | [0.043, 0.043, 0.043, 0.043, 0.043]
# | 6 | [0.054, 0.048, 0.054, 0.048, 0.054, 0.048]
# | 7 | [0.043, 0.043, 0.043, 0.043, 0.043, 0.043, 0.043]
# | 8 | [0.081, 0.081, 0.081, 0.081, 0.082, 0.081, 0.081, 0.082]
#
# ['livgmpms', 'hercilio', 'vsfqwzwc', 'zwjuadag', 'yvitzczf']
#
# hercilio
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
#
# cipher9.txt
#
# | m | Ic
# |-------
# | 1 | [0.047]
# | 2 | [0.053, 0.06]
# | 3 | [0.054, 0.065, 0.057]
# | 4 | [0.053, 0.06, 0.053, 0.06]
# | 5 | [0.047, 0.047, 0.047, 0.047, 0.047]
# | 6 | [0.081, 0.082, 0.081, 0.081, 0.081, 0.081]
#
# ['qeyviv', 'maurer', 'aoifsf', 'esmjwj', 'drlivi']
#
# maurer
#
# plaintext: bibliasagradatraducaojoaoferreiradealmeidaedicaore
